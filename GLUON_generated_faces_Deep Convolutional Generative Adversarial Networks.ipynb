# %% [markdown]
# #https://gluon.mxnet.io/chapter14_generative-adversarial-networks/dcgan.html
# nb: needs mxnet and gluon installed, CUDA support etc.
# pip install mxnet-cu90 --pre

# %%
from __future__ import print_function
import os
import matplotlib as mpl
import tarfile
import matplotlib.image as mpimg
from matplotlib import pyplot as plt

import mxnet as mx
from mxnet import gluon
from mxnet import ndarray as nd
from mxnet.gluon import nn, utils
from mxnet import autograd
import numpy as np
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
epochs = 2 # Set low by default for tests, set higher when you actually run this code.
batch_size = 64
latent_z_size = 100

use_gpu = True
ctx = mx.gpu() if use_gpu else mx.cpu()

lr = 0.0002
beta1 = 0.5

# %%
lfw_url = 'http://vis-www.cs.umass.edu/lfw/lfw-deepfunneled.tgz'
data_path = 'lfw_dataset'
if not os.path.exists(data_path):
    os.makedirs(data_path)
    data_file = utils.download(lfw_url)
    with tarfile.open(data_file) as tar:
        tar.extractall(path=data_path)
#downloads approx 50mb. nb: add dir to .gitignore before committing

# %%
target_wd = 64
target_ht = 64
img_list = []

def transform(data, target_wd, target_ht):
    # resize to target_wd * target_ht
    data = mx.image.imresize(data, target_wd, target_ht)
    # transpose from (target_wd, target_ht, 3)
    # to (3, target_wd, target_ht)
    data = nd.transpose(data, (2,0,1))
    # normalize to [-1, 1]
    data = data.astype(np.float32)/127.5 - 1
    # if image is greyscale, repeat 3 times to get RGB image.
    if data.shape[0] == 1:
        data = nd.tile(data, (3, 1, 1))
    return data.reshape((1,) + data.shape)

for path, _, fnames in os.walk(data_path):
    for fname in fnames:
        if not fname.endswith('.jpg'):
            continue
        img = os.path.join(path, fname)
        img_arr = mx.image.imread(img)
        img_arr = transform(img_arr, target_wd, target_ht)
        img_list.append(img_arr)
train_data = mx.io.NDArrayIter(data=nd.concatenate(img_list), batch_size=batch_size)

# %%
def visualize(img_arr):
    plt.imshow(((img_arr.asnumpy().transpose(1, 2, 0) + 1.0) * 127.5).astype(np.uint8))
    plt.axis('off')

for i in range(4):
    plt.subplot(1,4,i+1)
    visualize(img_list[i + 10][0])
plt.show()

# %%
# build the generator
nc = 3
ngf = 64
netG = nn.Sequential()
with netG.name_scope():
    # input is Z, going into a convolution
    netG.add(nn.Conv2DTranspose(ngf * 8, 4, 1, 0, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*8) x 4 x 4
    netG.add(nn.Conv2DTranspose(ngf * 4, 4, 2, 1, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*8) x 8 x 8
    netG.add(nn.Conv2DTranspose(ngf * 2, 4, 2, 1, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*8) x 16 x 16
    netG.add(nn.Conv2DTranspose(ngf, 4, 2, 1, use_bias=False))
    netG.add(nn.BatchNorm())
    netG.add(nn.Activation('relu'))
    # state size. (ngf*8) x 32 x 32
    netG.add(nn.Conv2DTranspose(nc, 4, 2, 1, use_bias=False))
    netG.add(nn.Activation('tanh'))
    # state size. (nc) x 64 x 64

# %%
# build the discriminator
ndf = 64
netD = nn.Sequential()
with netD.name_scope():
    # input is (nc) x 64 x 64
    netD.add(nn.Conv2D(ndf, 4, 2, 1, use_bias=False))
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf) x 32 x 32
    netD.add(nn.Conv2D(ndf * 2, 4, 2, 1, use_bias=False))
    netD.add(nn.BatchNorm())
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf) x 16 x 16
    netD.add(nn.Conv2D(ndf * 4, 4, 2, 1, use_bias=False))
    netD.add(nn.BatchNorm())
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf) x 8 x 8
    netD.add(nn.Conv2D(ndf * 8, 4, 2, 1, use_bias=False))
    netD.add(nn.BatchNorm())
    netD.add(nn.LeakyReLU(0.2))
    # state size. (ndf) x 4 x 4
    netD.add(nn.Conv2D(1, 4, 1, 0, use_bias=False))

# %%
# loss
loss = gluon.loss.SigmoidBinaryCrossEntropyLoss()

# initialize the generator and the discriminator
netG.initialize(mx.init.Normal(0.02), ctx=ctx)
netD.initialize(mx.init.Normal(0.02), ctx=ctx)

# trainer for the generator and the discriminator
trainerG = gluon.Trainer(netG.collect_params(), 'adam', {'learning_rate': lr, 'beta1': beta1})
trainerD = gluon.Trainer(netD.collect_params(), 'adam', {'learning_rate': lr, 'beta1': beta1})

# %%
from datetime import datetime
import time
import logging

real_label = nd.ones((batch_size,), ctx=ctx)
fake_label = nd.zeros((batch_size,),ctx=ctx)

def facc(label, pred):
    pred = pred.ravel()
    label = label.ravel()
    return ((pred > 0.5) == label).mean()
metric = mx.metric.CustomMetric(facc)

stamp =  datetime.now().strftime('%Y_%m_%d-%H_%M')
logging.basicConfig(level=logging.DEBUG)

for epoch in range(epochs):
    tic = time.time()
    btic = time.time()
    train_data.reset()
    iter = 0
    for batch in train_data:
        ############################
        # (1) Update D network: maximize log(D(x)) + log(1 - D(G(z)))
        ###########################
        data = batch.data[0].as_in_context(ctx)
        latent_z = mx.nd.random_normal(0, 1, shape=(batch_size, latent_z_size, 1, 1), ctx=ctx)

        with autograd.record():
            # train with real image
            output = netD(data).reshape((-1, 1))
            errD_real = loss(output, real_label)
            metric.update([real_label,], [output,])

            # train with fake image
            fake = netG(latent_z)
            output = netD(fake.detach()).reshape((-1, 1))
            errD_fake = loss(output, fake_label)
            errD = errD_real + errD_fake
            errD.backward()
            metric.update([fake_label,], [output,])

        trainerD.step(batch.data[0].shape[0])

        ############################
        # (2) Update G network: maximize log(D(G(z)))
        ###########################
        with autograd.record():
            fake = netG(latent_z)
            output = netD(fake).reshape((-1, 1))
            errG = loss(output, real_label)
            errG.backward()

        trainerG.step(batch.data[0].shape[0])

        # Print log infomation every ten batches
        if iter % 10 == 0:
            name, acc = metric.get()
            logging.info('speed: {} samples/s'.format(batch_size / (time.time() - btic)))
            logging.info('discriminator loss = %f, generator loss = %f, binary training acc = %f at iter %d epoch %d'
                     %(nd.mean(errD).asscalar(),
                       nd.mean(errG).asscalar(), acc, iter, epoch))
        iter = iter + 1
        btic = time.time()

    name, acc = metric.get()
    metric.reset()
    # logging.info('\nbinary training acc at epoch %d: %s=%f' % (epoch, name, acc))
    # logging.info('time: %f' % (time.time() - tic))

    # Visualize one generated image for each epoch
    # fake_img = fake[0]
    # visualize(fake_img)
    # plt.show()
# Out:
# INFO:root:speed: 66.13209298658809 samples/s
# INFO:root:discriminator loss = 1.657832, generator loss = 5.634634, binary training acc = 0.523438 at iter 0 epoch 0
# INFO:root:speed: 326.14086355164716 samples/s
# INFO:root:discriminator loss = 1.087212, generator loss = 13.394251, binary training acc = 0.889915 at iter 10 epoch 0
# INFO:root:speed: 328.2485848900867 samples/s
# INFO:root:discriminator loss = 0.182834, generator loss = 7.340075, binary training acc = 0.918899 at iter 20 epoch 0
# INFO:root:speed: 327.1711912869878 samples/s
# INFO:root:discriminator loss = 0.158965, generator loss = 12.049684, binary training acc = 0.923891 at iter 30 epoch 0
# INFO:root:speed: 328.3887295823995 samples/s
# INFO:root:discriminator loss = 0.282036, generator loss = 12.531912, binary training acc = 0.924162 at iter 40 epoch 0
# INFO:root:speed: 326.4291928268026 samples/s
# INFO:root:discriminator loss = 0.207998, generator loss = 15.850285, binary training acc = 0.913143 at iter 50 epoch 0
# INFO:root:speed: 326.0109449425184 samples/s
# INFO:root:discriminator loss = 0.269131, generator loss = 9.113283, binary training acc = 0.904969 at iter 60 epoch 0
# INFO:root:speed: 327.32558374904124 samples/s
# INFO:root:discriminator loss = 1.223196, generator loss = 22.451351, binary training acc = 0.891835 at iter 70 epoch 0
# INFO:root:speed: 325.4690196601456 samples/s
# INFO:root:discriminator loss = 1.707150, generator loss = 19.484840, binary training acc = 0.884356 at iter 80 epoch 0
# INFO:root:speed: 323.365174894083 samples/s
# INFO:root:discriminator loss = 0.660591, generator loss = 8.473566, binary training acc = 0.879722 at iter 90 epoch 0
# INFO:root:speed: 326.10560101074526 samples/s
# INFO:root:discriminator loss = 1.464369, generator loss = 10.111275, binary training acc = 0.862237 at iter 100 epoch 0
# INFO:root:speed: 319.12266648596534 samples/s
# INFO:root:discriminator loss = 0.707040, generator loss = 5.905409, binary training acc = 0.856700 at iter 110 epoch 0
# INFO:root:speed: 256.13581420201905 samples/s
# INFO:root:discriminator loss = 1.020870, generator loss = 6.545249, binary training acc = 0.852014 at iter 120 epoch 0
# INFO:root:speed: 321.6910951032475 samples/s
# INFO:root:discriminator loss = 0.527461, generator loss = 4.526540, binary training acc = 0.853948 at iter 130 epoch 0
# INFO:root:speed: 317.90722456515584 samples/s
# INFO:root:discriminator loss = 0.825983, generator loss = 7.461881, binary training acc = 0.853169 at iter 140 epoch 0
# INFO:root:speed: 321.4422468288115 samples/s
# INFO:root:discriminator loss = 0.369428, generator loss = 5.375793, binary training acc = 0.849545 at iter 150 epoch 0
# INFO:root:speed: 321.26605190561963 samples/s
# INFO:root:discriminator loss = 1.618005, generator loss = 8.983265, binary training acc = 0.850107 at iter 160 epoch 0
# INFO:root:speed: 317.76008257829903 samples/s
# INFO:root:discriminator loss = 0.405839, generator loss = 3.946433, binary training acc = 0.851380 at iter 170 epoch 0
# INFO:root:speed: 319.62651978172056 samples/s
# INFO:root:discriminator loss = 0.498842, generator loss = 6.705444, binary training acc = 0.854584 at iter 180 epoch 0
# INFO:root:speed: 321.3302752732862 samples/s
# INFO:root:discriminator loss = 0.398140, generator loss = 6.335878, binary training acc = 0.851644 at iter 190 epoch 0
# INFO:root:speed: 320.4809157571257 samples/s
# INFO:root:discriminator loss = 0.953504, generator loss = 2.168911, binary training acc = 0.852068 at iter 200 epoch 0
# INFO:root:speed: 325.40431479557634 samples/s
# INFO:root:discriminator loss = 0.591410, generator loss = 4.840137, binary training acc = 0.914062 at iter 0 epoch 1
# INFO:root:speed: 323.1938702410751 samples/s
# INFO:root:discriminator loss = 0.675528, generator loss = 5.385576, binary training acc = 0.911222 at iter 10 epoch 1
# INFO:root:speed: 321.05126334447215 samples/s
# INFO:root:discriminator loss = 0.386466, generator loss = 3.522240, binary training acc = 0.876116 at iter 20 epoch 1
# INFO:root:speed: 321.61246982286093 samples/s
# INFO:root:discriminator loss = 0.741549, generator loss = 9.747116, binary training acc = 0.884829 at iter 30 epoch 1
# INFO:root:speed: 319.32386511657234 samples/s
# INFO:root:discriminator loss = 0.171855, generator loss = 7.202600, binary training acc = 0.863948 at iter 40 epoch 1
# INFO:root:speed: 320.95107577342696 samples/s
# INFO:root:discriminator loss = 0.196375, generator loss = 6.295847, binary training acc = 0.868260 at iter 50 epoch 1
# INFO:root:speed: 319.5934127687135 samples/s
# INFO:root:discriminator loss = 0.694266, generator loss = 5.713688, binary training acc = 0.868084 at iter 60 epoch 1
# INFO:root:speed: 321.48420815628486 samples/s
# INFO:root:discriminator loss = 0.585865, generator loss = 8.858433, binary training acc = 0.871369 at iter 70 epoch 1
# INFO:root:speed: 325.0166252377672 samples/s
# INFO:root:discriminator loss = 1.553136, generator loss = 2.562192, binary training acc = 0.862751 at iter 80 epoch 1
# INFO:root:speed: 319.4583919941258 samples/s
# INFO:root:discriminator loss = 0.509670, generator loss = 3.804680, binary training acc = 0.866758 at iter 90 epoch 1
# INFO:root:speed: 321.86119590892196 samples/s
# INFO:root:discriminator loss = 0.788893, generator loss = 7.807653, binary training acc = 0.869895 at iter 100 epoch 1
# INFO:root:speed: 319.773110204704 samples/s
# INFO:root:discriminator loss = 0.981627, generator loss = 8.039876, binary training acc = 0.865709 at iter 110 epoch 1
# INFO:root:speed: 321.4830531107521 samples/s
# INFO:root:discriminator loss = 0.756934, generator loss = 5.677656, binary training acc = 0.861506 at iter 120 epoch 1
# INFO:root:speed: 319.838262330436 samples/s
# INFO:root:discriminator loss = 0.534135, generator loss = 3.814502, binary training acc = 0.862834 at iter 130 epoch 1
# INFO:root:speed: 321.546592942721 samples/s
# INFO:root:discriminator loss = 0.241085, generator loss = 6.182279, binary training acc = 0.862977 at iter 140 epoch 1
# INFO:root:speed: 321.2921996392523 samples/s
# INFO:root:discriminator loss = 1.200176, generator loss = 13.342852, binary training acc = 0.866360 at iter 150 epoch 1
# INFO:root:speed: 321.11501672352824 samples/s
# INFO:root:discriminator loss = 0.588599, generator loss = 2.992008, binary training acc = 0.863888 at iter 160 epoch 1
# INFO:root:speed: 320.13578452126103 samples/s
# INFO:root:discriminator loss = 0.426289, generator loss = 4.108076, binary training acc = 0.860289 at iter 170 epoch 1
# INFO:root:speed: 318.71913676991613 samples/s
# INFO:root:discriminator loss = 0.379419, generator loss = 3.580815, binary training acc = 0.861317 at iter 180 epoch 1
# INFO:root:speed: 320.61182428397393 samples/s
# INFO:root:discriminator loss = 0.424907, generator loss = 4.975601, binary training acc = 0.864324 at iter 190 epoch 1
# INFO:root:speed: 318.27020464300114 samples/s
# INFO:root:discriminator loss = 0.161358, generator loss = 5.561509, binary training acc = 0.863767 at iter 200 epoch 1

# %%
num_image = 8
for i in range(num_image):
    latent_z = mx.nd.random_normal(0, 1, shape=(1, latent_z_size, 1, 1), ctx=ctx)
    img = netG(latent_z)
    plt.subplot(2,4,i+1)
    visualize(img[0])
plt.show()

# %%
num_image = 12
latent_z = mx.nd.random_normal(0, 1, shape=(1, latent_z_size, 1, 1), ctx=ctx)
step = 0.05
for i in range(num_image):
    img = netG(latent_z)
    plt.subplot(3,4,i+1)
    visualize(img[0])
    latent_z += 0.05
plt.show()
